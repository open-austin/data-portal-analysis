# %%
import json

# %%
data_json = open('datasets.json')
data_str = data_json.read()
data_dict = json.loads(data_str)

# %%
for item in data_dict['datasets']:
    print item['id'], ':', item['name'], '\n'
    for col in item['columns']:
        print col['name']
    print '\n\n'
# Out:
# trxj-f8br : 911 ADDRESSING - ADDRESS CHANGES
#
# OLD HOUSE #
# OLD FRACTION
# OLD DIR
# OLD STREET NAME
# OLD TYPE
# OLD BLDG
# OLD UNIT
# NEW HOUSE #
# NEW FRACTION
# NEW DIR
# NEW STREET NAME
# NEW TYPE
# NEW BLDG
# NEW UNIT
# TAX ID
# EFFECTIVE DATE
# KEY NUMBER
#
#
#
# 5tye-7ray : Water Quality Sampling Data
#
# WATERSHED
# SAMPLE_DATE
# SITE_NAME
# SITE_TYPE
# MEDIUM
# PARAM_TYPE
# PARAMETER
# QUALIFIER
# RESULT
# UNIT
# FILTER
# SAMPLE_ID
# SAMPLE_SITE_NO
# DEPTH_IN_METERS
# METHOD
# QC_FLAG
# PROJECT
# Location
# DATA_REF_NO
# LAT_DD_WGS84
# LON_DD_WGS84
# SAMPLE_REF_NO
# TIME_NULL
# QC_TYPE
#
#
#
# qe89-agqj : Haulers Licensed by City of Austin
#
# Type of Hauler
# Name of Hauler
# Phone
# Website
#
#
#
# 3237-g9rs : Economic Development Compliance: Active Chapter 380 Agreement Evaluation Criteria
#
# Firm
# Total New Jobs Committed
# Average Wage
# Total Investment Committed
# Matrix Score
# Net Fiscal Benefit Estimated by WebLOCI
#
#
#
# ergh-7g8p : 2012 APD Crash Fatality Data
#
# RoadofAccident
# Date
# Day
# Time
# Type
# WHO DIED
# TYPE OF ROAD
#
#
#
# fc48-h8gp : Trust Fund Documents
#
# Year
# Event
# Event Start Date
# Event Final Date
# Fund
# City Council Resolution Authorization
# City-CELOC Agreement
# City-COTA Agreement
# Application to Participate
# Award Letter
# Comptroller Contribution
# LOC Contribution
# Total Trust Fund
# Event Support Agreement
# Attendance Certification, CELOC
# Attendance Certification, COTA
# Attendance Certification, CoA
# Total Attendance at Primary Event
# Estimated OOS Attendance at Primary Event
# Reimb Request
#
#
#
# wr7f-jdtu : Austin Energy Green Choice Sales
#
# GreenChoice Sales by kWh
# Sales by kWh
#
#
#
# kyp9-ynfw : Bond Program Spending Summary
#
# Row ID
# Date
# Fiscal Year
# Fiscal Quarter
# Bond Program Year
# Proposition
#  Allocated
# Expended
# % Expended
#  Encumbered
# % Encumbered
#  Available
# % Available
#
#
#
# askx-pbnh : 2013: ECAD Multi-Family Energy Audit and EUI Data
#
# Community Name
# TCAD or WCAD Property ID(s)
# Audit Date
# Percent Duct Leakage
# Recommend Duct Leakage
# Attic R-Value
# Window Screens
# Year Built
# Common Wash Dryer
# Utilities
# Total Units
# Community EUI (kWh/sqft/yr)
# As of
# Address
#
#
#
# 4gv8-96x2 : Municipal Court Caseload Information FY 2013
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
# Offense Cross Street Name
# School Zone
# Construction Zone
# Case Closed
# Agency Code
# Officer Code
#
#
#
# gjtj-jt2d : EMS - Incidents by Month
#
# Month Key
# Month-Year
# Total Incidents
# Austin Incidents
# Travis County Incidents
# Other Area Incidents
# Combined Austin and Travis County Incidents
# Austin P1 Incidents
# Austin P2 Incidents
# Austin P3 Incidents
# Austin P4 Incidents
# Austin P5 Incidents
# Travis County P1 Incidents
# Travis County P2 Incidents
# Travis County P3 Incidents
# Travis County P4 Incidents
# Travis County P5 Incidents
# Overall On-Time Compliance
# Austin On-Time Compliance
# Travis County On-Time Compliance
# Austin P1 On-Time Compliance
# Austin P2 On-Time Compliance
# Austin P3 On-Time Compliance
# Austin P4 On-Time Compliance
# Austin P5 On-Time Compliance
# Travis County P1 On-Time Compliance
# Travis County P2 On-Time Compliance
# Travis County P3 On-Time Compliance
# Travis County P4 On-Time Compliance
# Travis County P5 On-Time Compliance
# Target On-Time Compliance
#
#
#
# sswp-u5uh : AustinGO Keyword Search
#
# Keyword
# Unique Pageviews
#
#
#
# rka3-mjzi : 2013: ECAD Commercial Portfolio Manager Reported Data
#
# TCAD or WCAD Property ID(s)
# Floor Area (sqft)
# Building Type
# Reported Portfolio Manager Energy Star Score
# Reported Portfolio Manager Site kBTU/sqft
# As of
# Address
#
#
#
# ei2n-fehk : APD Incident Extract 2009
#
# Incident Report Number
# Crime Type
# Date
# Time
# LOCATION_TYPE
# ADDRESS
# LONGITUDE
# LATITUDE
# Location 1
#
#
#
# 7j64-2qf8 : African American Quality of Life (AAQL) Performance Measures
#
# Fiscal Year
# Total Clients
# Blood Glucose
# Blood Pressure
# Pregnancy Test
# IMM
# HIV
# Vision
# WIC
# Dental
# Stroke Info
# Cancer Info
# General Health Info
# Presenta-tions
# Referrals
# Surveys
# MAP
# Prostate Exams
#
#
#
# gt3n-akq9 : The Austin Internet and Global Citizens Project
#
# v1
# v2
# v3
# q1a
# q1b
# q2e
# q2e1
# q2f
# q2g
# q2h
# q2i
# q2j
# q2a
# q2b
# q2c
# q2d
# q3a
# q3b
# q3c
# q3d
# q3e
# q3f
# q3g1
# q3g2
# q3g3
# q3g4
# q3g5
# q4a
# q4b1
# q4b3
# q4b4
# q4b2
# q4c
# q4d1
# q4d2
# q4d3
# q4d4
# q4d5
# q4d6
# q4d7
# q4d8
# q4d9
# q4d9a
# q4e1
# q4e2
# q4e3
# q4e4
# q4e5
# q4e6
# q4e7
# q4e7a
# q4f1
# q4f2
# q4f3
# q4f4
# q4f5
# q4f6
# q4g1
# q4g2
# q4g3
# q4g4
# q4h1
# q4h2
# q4h3
# q4h4
# q4h5
# q4h6
# q4h7
# q4h8
# q4h9
# q4h10
# q4h11
# q4h12
# q4i1
# q4i2
# q4i3
# q4i4
# q4i5
# q4i6
# q4i7
# q4j1
# q4j2
# q4j3
# q4j4
# q4j5
# q4j6
# q4j7
# q4j8
# q4k1
# q4k2
# q4k3
# q4k4
# q4k5
# q4k6
# q4k7
# q4k8
# q5a1
# q5a2
# q5a3
# q5a4
# q5a5
# q5b1a
# q5b1b
# q5b1c
# q5b1d
# q5b1e
# q5c4a
# q5c4b
# q5c4c
# q5c4d
# q5c4e
# q5c4f
# q5c8a
# q5c8b
# q5c8c
# q5c8d
# q5c8e
# q5c8f
# q5c5a
# q5c5b
# q5c5c
# q5c5d
# q5c5e
# q5c5f
# q5c1a
# q5c1b
# q5c1c
# q5c1d
# q5c1e
# q5c1f
# q5c9a
# q5c9b
# q5c9c
# q5c9d
# q5c9e
# q5c9f
# q5c10a
# q5c10b
# q5c10c
# q5c10d
# q5c10e
# q5c10f
# q5c11a
# q5c11b
# q5c11c
# q5c11d
# q5c11e
# q5c11f
# q5c2a
# q5c2b
# q5c2c
# q5c2d
# q5c2e
# q5c2f
# q5c3a
# q5c3b
# q5c3c
# q5c3d
# q5c3e
# q5c3f
# q5c6a
# q5c6b
# q5c6c
# q5c6d
# q5c6e
# q5c6f
# q5c7a
# q5c7b
# q5c7c
# q5c7d
# q5c7e
# q5c7f
# q5c12a
# q5c12b
# q5c12c
# q5c12d
# q5c12e
# q5c12f
# q5c13a
# q5c13b
# q5c13c
# q5c13d
# q5c13e
# q5c13f
# q5c14a
# q5c14b
# q5c14c
# q5c14d
# q5c14e
# q5c14f
# q5c1f1
# q5c9f1
# q5c10f1
# q5c11f1
# q5c2f1
# q5c3f1
# q5c4f1
# q5c5f1
# q5c6f1
# q5c7f1
# q5c8f1
# q5c12f1
# q5c13f1
# q5c14f1
# q5d1e
# q5d1d
# q5d1c
# q5d1b
# q5d1a
# q5d1f
# q5d1f1
# q5e
# q5f1
# q5f2
# q5f3
# q5f4
# q5f5
# q5f4a
# q5g
# q5h
# q6a1
# q6a2
# q6a3
# q6a4
# q6a5
# q6a6
# q6a7
# q6a8
# q6a9
# q6a10
# q6a11
# q6a12
# q6a13
# q6a14
# q6a15
# q6a16
# q6b1
# q6b2
# q6b3
# q6b4
# q6b5
# q6b6
# q6b7
# q6b8
# q6b9
# q6b9a
# q7a
# q7b
# q7c
# q7d
# q8a1
# q8a2
# q8a3
# q8a4
# q8a5
# q8a6
# q8a7
# q8a7a
# q8b
# q8c
# q8c1
# q8d
# q8e
# q8f
# q9a1
# q9a2
# q9b
# q9c
# q9c1
# q9d
# q9e
# q9f
# q9g1
# q9g2
# q9h1
# q9h2
# q9i
# q9j
# q9k
# q9l
# q9m
# q9n
# q9o
# q9p
# q9q
# q9r
# q9s
# q9t
# q9u1
# q9u2
# q9u3
# q9u4
# q9u5
# q9u6
# q9u7
# q9u6a
# q10
# zip4
# zip5
#
#
#
# uqe6-trgb : Municipal Court Caseload Information FY 2014
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
# Offense Cross Street Name
# School Zone
# Construction Zone
# Case Closed
# Agency Code
# Officer Code
#
#
#
# d7k5-jyb8 : Draft Imagine Austin Indicators
#
# No.
# Indicator
# Definition
# Importance
# Analysis
# IA Theme
# Data
# Units
# Primary Source
#  Source Year
# Primary Source Link
# Second Source
# Third Source
#
#
#
# 7ti8-tuax : Council Member Tovo Resolutions
#
# Lead
# DATE
# Cosponsor
# Follow Up/Return Data
# Topic
# CIUR Update
# Number
#
#
#
# xj3h-ppw2 : Beneficiary Demographics Fiscal Year 2010-2011
#
# Investment Category
# Program
# MFI 0-30 percent
# MFI 31-50 percent
# MFI 51-60%
# MFI 61-80%
# MFI More than 80%
# White
# Black/African American
# Asian
# Amer. Indian/ Alaskan Native
# Native Hawaiian/ Other Pacific islander
# Amer. Indian/ Alaskan Native & White
# Asian & White
# Black/African American & White
# Am. Indian/Alaskan Native & Black/African American
# Other Multi-Racial
# White-Hispanic
# Black-Hispanic
# Female Head of Household
# Elderly
# Person w/ disability in Household
#
#
#
# 73wi-y5aa : NET Deficiencies (OBSOLETE)
#
# Folder Id
# Address
# Case Number
# Date Opened
# Property Type
# Case Status
# Primary Reported Violation
# Propx
# PropY
# Deficiency
# Latitude
# Longitude
# Location
#
#
#
# fb53-k8de : Austin Animal Center FY15 Outcomes *Updated Hourly*
#
# Animal ID
# Name
# Outcome Date
# Outcome Time
# Outcome Type
# Outcome Subtype
# Animal Type
# Sex upon Outcome
# Age upon Outcome
# Breed
# Color
#
#
#
# r6sg-xka2 : APD Incident Extract 2008
#
# Incident Report Number
# Crime Type
# Date
# Time
# LOCATION_TYPE
# ADDRESS
# LONGITUDE
# LATITUDE
# Location 1
#
#
#
# 3ghn-wv5a : 2012 Austin Animal Center Intakes
#
# Animal ID
# Intake Date
# Intake Type
# Intake Condition
# Animal Type
# Sex upon Intake
# Age upon Intake
# Primary Breed
# Primary Color
#
#
#
# de95-4khj : Licensed Private Organic and Composting Haulers
#
#  Organic & Composting Hauler
# Phone
# Website
# Address
#
#
#
# xbbp-8bw7 : November Austin Animal Center Outcomes
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# a6pm-qynf : Austin Energy System Peak Demand
#
# Fiscal year
# Megawatts (MW)
# Date Set
#
#
#
# yqxj-7evp : City of Austin Public Art Collection
#
# Artist Full Name
# Art Title
# Art Location Name
# Art Location Street Address
# Art Location City
# Art Location State
# Art Location Zip
# Images
# Web Detail Page
# Location
#
#
#
# hjeh-idye : Austin Animal Center FY15 Intakes *Updated Hourly*
#
# Animal ID
# Name
# Intake Date
# Intake Time
# Found Location
# Intake Type
# Intake Condition
# Animal Type
# Sex upon Intake
# Age upon Intake
# Breed
# Color
#
#
#
# paa2-kvza : Resolutions Summary
#
# Meeting Date
# Topic
# Agenda Posting Language
# Summary
#
#
#
# nttt-2a35 : Adult and Children Vaccinations Provided
#
# CLINICS:
# 12-Jun
# 12-Jul
# 12-Aug
# 12-Sept
# 12-Oct
# 12-Nov
# 12-Dec
# 13-Jan
# 13-Feb
# 13-Mar
# 13-Apr
# 13-May
# 13-Jun
# 13-Jul
# 13-Aug
# 13-Sep
# 13-Oct
# 13-Nov
# 13-Dec
# 14-Jan
# 14-Feb
# 14-Mar
# 14-Apr
# 14-May
# 14-Jun
# 14-July
# 14-Aug
# 14-Sep
# 14-OCT
# 14-Nov
# 14-Dec
# 15-Jan
# 15-Feb
# 15-Mar
# 15-Apr
# 15-May
# 15-Jun
# 15-July
# 15-Aug
#
#
#
# 6v78-dj3u : Health and Human Services Locations
#
# Facility Name
# Street Address
# Address Line 2
# Zip Code
# Hours
# Website
# Phone Number
# Other Phone
#
#
#
# kumu-nbtd : 911 Addressing - Street Name Master List
#
# PRE DIR
# PRE TYPE
# STREET NAME
# STREET TYPE
# STATUS
#
#
#
# 64cq-wf5u : Austin Fire Stations
#
# Name
# Jurisdiction Name
# Y
# X
# Location 1
#
#
#
# gr59-ids7 : APD Incident Extract 2011
#
# Incident Report Number
# Crime Type
# Date
# Time
# LOCATION_TYPE
# ADDRESS
# LONGITUDE
# LATITUDE
# Location 1
#
#
#
# qwjz-np8k : Creative Content Incentive Program Agreements
#
# Firm
# Project Description
# Date Approved
# City Council Ordinance/Resolution
# Agreement
# Amendment Documents
# Status
# Incentive Basis
# Total Estimated Incentive
# Total Payments Issued
# Location
# Final Report
# Independent Reviewer Report
#
#
#
# 4c6h-tv2y : APD Incident Extract 2010
#
# Incident Report Number
# Crime Type
# Date
# Time
# LOCATION_TYPE
# ADDRESS
# LONGITUDE
# LATITUDE
# Location 1
#
#
#
# 7neq-k7nf : Economic Development Compliance: Family Business Loans
#
# Firm
# Loan
# Repayment Terms
# Job Creation Commitment
#
#
#
# tv4x-8thz : Economic Development Compliance: Texas Enterprise Zone Nominations
#
# Firm
# Application Date
# Total Investment
# Total Announced Jobs
# Total Jobs Retained
# State Status
# Chapter 380 Agreement
# City Council Resolution
# RCA
#
#
#
# 4i8t-nckg : City of Austin Licensed Private Waste Haulers
#
# Private Waste Hauler
# Phone
# Website
# Address
#
#
#
# pxe3-na7s : Economic Development Compliance: Chapter 380 Agreement Basic Information
#
# Firm
# Project Description
# Date Approved
# City Council Ordinance/Resolution
# Agreement
# Amendment Documents
# Status
# Total Investment
# Existing Jobs Retained
# New Jobs Created
# Total Jobs
# Average Wage
# Incentive Basis
# Total Estimated Incentive
# Total Payments Issued
# Location
#
#
#
# wrwk-skv6 : 2011 Animal Intake Report (Cats and Dogs Exclusively)
#
# Intake Date
# Intake Type
# Intake Subtype
# Animal Type
# Sex
# Years Old
# Months Old
# Days Old
# Intake Condition
# Breed
# Coat Color Pattern
#
#
#
# 3ebq-e9iz : Purchase Order Quantity Price detail for Commodity/Goods procurements
#
# COMMODITY
# COMMODITY_DESCRIPTION
# EXTENDED_DESCRIPTION
# QUANTITY
# UNIT_OF_MEASURE
# UNIT_OF_MEAS_DESC
# UNIT_PRICE
# ITM_TOT_AM
# MASTER_AGREEMENT
# CONTRACT_NAME
# PURCHASE_ORDER
# AWARD_DATE
# VENDOR_CODE
# LGL_NM
# AD_LN_1
# AD_LN_2
# CITY
# ST
# ZIP
# CTRY
# DATA_BUILD_DATE
#
#
#
# x442-h34c : Construction Plans in SMBR's Plan Room
#
# Bid Date
# Pre Bid Date
# Organization
#  Project Number
# Department
# Project Name
# Addendum
# Rec'd Date
#
#
#
# hek3-kuva : Percent of Short-term Rentals Issued by Census Tract
#
# Census Tract
# 3% Cap
# Licenses Issued
# Percent Issued
# Licenses Remaining
#
#
#
# e8fp-i3ts : CIVIC Projects List
#
# Project ID
# Name
# Status
# Category
# Sponsor Department
# Description
# Project Manager
# Phone Number
# Email
#
#
#
# 8c6z-qnmj : Austin Finance Online eCheckbook
#
# FY_DC
# PER_CD
# DEPT_CD
# DEPT_NM
# FUND_CD
# FUND_NM
# DIV_CD
# DIV_NM
# GP_CD
# GP_NM
# OCAT_CD
# OCAT_NM
# OBJ_CD
# OBJ_NM
# LGL_NM
# VEND_CUST_CD
# VEND_CUST_IND
# RFED_DOC_CD
# RFED_DOC_DEPT_CD
# RFED_DOC_ID
# COMM_CD
# COMM_DSCR
# CHK_EFT_ISS_DT
# CVL_CHK_STA_DV
# RFED_VEND_LN_NO
# RFED_COMM_LN_NO
# RFED_ACTG_LN_NO
# RF_DOC_CD
# RF_DOC_DEPT_CD
# RF_DOC_ID
# ACTG_LN_DSCR
# AMOUNT
# CAL_YEAR
# CAL_MONTH
#
#
#
# 8jyt-x94k : Municipal Court Caseload Information **Dataset removal in 2 months on September 1, 2014
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
# Offense Cross Street Check
#  Offense Cross Street
# School Zone
# Construction Zone
# Case Closed
#
#
#
# i26j-ai4z : 311 Unified Data
#
# Service Request (SR) Number
# SR Type Code
# SR Description
# Owning Department
# Method Received
# SR Status
# Status Change Date
# Created Date
# Last Update Date
# Close Date
# SR Location
# Street Number
# Street Name
# City
# Zip Code
# County
# State Plane X Coordinate
# State Plane Y Coordinate
# Latitude Coordinate
# Longitude Coordinate
# (Latitude.Longitude)
# Council District
# Map Page
# Map Tile
#
#
#
# u3yy-shmz : Austintexas.gov - Community Registry - Updated once a Month
#
# Association Name
# Association Category
# Association Email
# Association Zip Code
# Planning ID #
# Primary Contact Name
# Primary Contact Phone
# Primary Address
# Primary Contact Zipcode
# Primary Contact Email
# Secondary Contact Name
# Secondary Contact Phone
# Secondary Contact Address
# Secondary Contact Zipcode
# Secondary Contact Email
# Number of Households
# Meeting Information
#
#
#
# ykw4-j3aj : Declared  Dangerous Dogs
#
# First Name
# Last Name
# Address
# Zip Code
# Description of Dog
# Location
#
#
#
# hut9-4n8t : 3-1-1 Calls And Service Requests
#
# Fiscal Year
# Calls Answered
# Service Requests
#
#
#
# atrx-cf82 : February 2014 Austin Animal Center Total Live Outcome Rates
#
# Animal Type
# Total Live Outcome Rate
#
#
#
# 959k-a8yh : Google Analytics for www.austintexas.gov
#
# Page Title
# Unique Pageviews
# New Visits
# Avg. Visit Duration
# Organic Searches
#
#
#
# g5k8-8sud : Program Budget Operating Budget Vs Expense Raw Data
#
# BUDGET_FISCAL_YEAR
# THRU_QUARTER
# DEPT_ROLLUP
# DEPT_ROLLUP_NAME
# DEPARTMENT_CODE
# DEPARTMENT_NAME
# FUND_CODE
# FUND_NAME
# PROGRAM_CODE
# PROGRAM_NAME
# ACTIVITY_CODE
# ACTIVITY_NAME
# UNIT_CODE
# UNIT_NAME
# EXPENSE_CODE
# EXPENSE_NAME
# BUDGET
# EXPENDITURES
# KEY
#
#
#
# p6pb-jvsm : Economic Development Compliance: Chapter 380 Individual Payments and Compliance Reports
#
# Firm
# Project
# Year
# Payment
# Payment Date
# Compliance Report/Certificate
# Independent Party Compliance Report
#
#
#
# rfif-mmvg : Recycling Schedules
#
# HOUSE_NO
# FRACTION
# HSE_SUFF
# STREET_NAM
# STREET_TYP
# ST_DIR
# UNIT_NO
# CITY
# STATE
# ZIP
# COLLECTION DAY
# COLLECTION WEEK
#
#
#
# ec78-i9z5 : Watersheds
#
# CODE
# WATERSHED NAME
# DISCHARGE INTO
# RSMP
# WATERSHED ID
#
#
#
# h3i4-5e5v : Unclaimed Property
#
# Last
# First
#
#
#
# kz4x-q9k5 : Austin Animal Center Stray Map
#
# Animal ID
# Found Location
# At AAC
# Intake Date
# Type
# Looks Like
# Color
# Sex
# Age
# Image Link
#
#
#
# 5tx2-pk4n : Bicycle Rack Requests
#
# Request Date
# Location
# Install?
# Requestor
# Galv
# Green
# Cables
# Galv
# Green
# Cables
# Delivered
# Installed
# Central Buisness District
# CBD  #of Racks
# GIS ID2
# x
# y
# GeoLocation
#
#
#
# 8aah-diw2 : Licensed Private Recycling Haulers
#
# Private Recycling Hauler
# Phone
# Website
# Address
#
#
#
# bqav-9x6a : Lobbyists
#
# Last Name
# First Name
# Address
# Expiration Date
# Client
# Client Address
# Nature of Business
#
#
#
# 84ih-p28j : Contract Catalog
#
# DOC_CD
# DOC_DEPT_CD
# DOC_ID
# DOC_VERS_NO
# DOC_DSCR
# CONTRACT_SYNOPSIS
# CONTRACT_CONTACT_NM
# CONTRACT_CONTACT_VOICE_PH_NO
# CONTRACT_CONTACT_EMAIL_AD
# MA_PRCH_LMT_AM
# MA_ITD_ORD_AM
# MA_DO_RFED_AM
# EFBGN_DT
# EFEND_DT
# GNRC_PO_RPT_1
# RPT_DSCR
# BRD_AWD_DT
# BRD_AWD_NO
# CAT_DSCR
# DOC_VEND_LN_NO
# VEND_CUST_CD
# LGL_NM
# ALIAS_NM
# SO_DOC_CD
# SO_DOC_DEPT_CD
# SO_DOC_ID
# TODAY
# ROW_KEY
#
#
#
# ecmv-9xxi : Restaurant Inspection Scores
#
# Restaurant Name
# Zip Code
# Inspection Date
# Score
# Address
# Facility ID
# Process Description
#
#
#
# b4y9-5x39 : APD Incident Extract YTD
#
# Incident Report Number
# Crime Type
# Date
# Time
# LOCATION_TYPE
# ADDRESS
# LONGITUDE
# LATITUDE
# Location 1
#
#
#
# zzix-yxi4 : Austin Energy General Fund Transfer
#
# Budget
# Amount in Millions
#
#
#
# c69b-fkfx : Municipal Court Caseload Information FY 2010
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
# Offense Cross Street Name
# School Zone
# Construction Zone
# Case Closed
# Agency Code
# Officer Code
#
#
#
# 32y8-3gbr : Affordable Housing Inventory
#
# Contract ID #
# Name
# Developer/Owner
# Unit Type
# Development Program
# Address
# Zip Code
# Council District
# Contact Phone Number
# Contact E-mail
# Own/Rent
# Total Units
# Total Affordable Units
# Status
# Affordability Period Start Date
# Affordability Period Start Year
# Affordabilty Period
# Affordability Period Expiration Date
# Units at 30% MFI
# Units at 40% MFI
# Units at 50% MFI
# Units at 60% MFI
# Units at 65% MFI
# Units at 80% MFI
# Market Rate Units
# City Funding Amount
# Approx. % of Funds Leveraged
# Location 1
#
#
#
# 7dis-buys : Draft Additional Imagine Austin Indicators
#
# Indicator
# Original Name
# Primary Source
# Primary Source Link
# Second Source
# Third Source
# IA Theme
# Origination
# Comments
#
#
#
# yrpa-wmth : 2012 Austin Animal Center Outcomes
#
# Animal ID
# Outcome Date
# Outcome Type
# Animal Type
# Sex upon Outcome
# Age upon Outcome
# Primary Breed
# Primary Color
#
#
#
# 54hu-zyfw : Percent of Short-Term Rentals Issued by Census Tract
#
# Census Tract
# 3% Cap
# Licenses Issued
# Percent Issued
# Licenses Remaining
#
#
#
# h4as-bnn4 : Analytics Austin GO Mobile Views
#
# Mobile
# Unique Pageviews
#
#
#
# 6s5y-evgf : Building a Better Austin: Action Steps
#
# Priority Area
# Work Group
# Contact Name
# Rec #
# Zucker Recommendation
# Staff Feedback
# Department Recommendations and Action Step(s)
# Start Date
# End Date
# Financial Considerations
# One-time or Operating Cost
# Zucker Recommended Phase
#
#
#
# xaxa-886r : Pool Schedule2015
#
# Pool Name
# Status
# Open Date
# Weekday
# Weekend
# Close Date
# Weekday Closure
# Pool Type
# Phone
# Location 1
# Website
#
#
#
# vxq2-zjmn : Solar Program Current Incentive Levels and Available Capacity
#
# Program and Incentive Level
# Capacity Requested kW-ac
# Capacity Reserved kW-ac
# Capacity Installed kW-ac
# Capacity Available kW-ac
#
#
#
# uxwx-55kj : Current Small Business Enterprise, SBE, Certfied Vendors
#
# VENDOR_CODE
# LEGAL_NAME
# ALIAS
# PRINCIPLE_CONTACT
# EMAIL
# PHONE
# PHONE_EXT
# FAX
# FAX_EXT
# STREET_1
# STREET_2
# CITY
# STATE
# ZIP
#
#
#
# vk3r-6prc : Watershed Reach Index and Problem Scores
#
# Watershed ID
# Watershed Name
# Integrity Score ID
# Watershed Reach
# Year of Observation
# Index Phase
# Index Source Type
# Overall
# Aquatic Life
# Contact Recreation
# Eutrophication
# Habitat
# Non-Contact Recreation
# Sediment
# Vegetation
# Water Quality
# Animal Waste Problem
# Construction Runoff Problem
# Fertilizer Problem
# Litter Problem
# Riparian Vegetation Problem
# Sediment Problem
# Sewage Problem
# Stability Problem
# Water Quality Problem
# CREATED_BY
# CREATED_DATE
# MODIFIED_BY
# MODIFIED_DATE
#
#
#
# afwp-v695 : Austin Code Complaint Case Events
#
# EVENT_ID
# CASE_ID
# NAME
# STATUS_DATE
# STATUS
# NOTES
# CONTACT
# DATE_UPDATED
#
#
#
# utnt-hag5 : FY12 Day Labor Placements
#
# Date
# Day of Week
# Log Out 6-6:59am
# Log Out 7-7:59am
# Log Out 8-8:59am
# Log Out 9-9:59am
# Log Out 10-10:59am
# Log Out 11-11:59am
# Log Out 12-12:59pm
# Log Out 1-1:59pm
# Total Signed Out
# Total Contractors
# Total Signed In
# Stayed Until Close
# Weather / Holiday
#
#
#
# bptg-ndvw : EMS - Ambulance Responses by Month
#
# Month Key
# Month-Year
# Total System Responses
# Total Austin Responses
# Total Travis County Responses
# Other Area Responses
# Combined City and County Responses
# COA Unit Responses into TC
# TC Unit Responses into COA
# Percent COA Responses by TC
# Percent TC Responses by COA
#
#
#
# dtkn-v97q : Golf Courses in Austin
#
# Name
# Website
# Phone
# Book Tee Time
# View Scorecard
# Location
#
#
#
# gzqu-rstf : Community Connections Program: 100 Gigabit Speed (Google Fiber) Public Facilities
#
# File Name
# Application Document (.pdf)
# Category
# Business Name
# Location Name
# Location Address
# Location City
# Location State
# Location ZIP
# Location County
# Location
#
#
#
# ig6i-wwx7 : EMS - System Response Time
#
# Month
# Incident Count
# Goal Met Count
# Goal Met Percentage
# Target Percentage
#
#
#
# bcku-z9d8 : Austin Police Forensics Quality Records
#
# Folder
# Document Name
#
#
#
# cusd-m48y : Utility Payment Methods
#
# Fiscal Year
# Authorized Pay Stations via Western Union (ex. ACE cash Express, HEB, Money Box, Randalls)
# Online Banking (via customers bank)
# Bill Matrix  (via phone or Austin Energy Website) (credit, debit,    e-check)
# Austin Energy Website (registered with Online Customer Care) (e-check)
# Electronic Fund Transfer (draft by AE)
# Misc. (ex. Collections, IRS)
# Walk-in Payment Centers
# Mail
# % Manual Payments
# % Electronic Payments
#
#
#
# jam6-aawd : Austin Animal Center FY14 Intakes
#
# Animal ID
# Name
# Intake Date
# Intake Time
# Found Location
# Intake Type
# Intake Condition
# Animal Type
# Sex upon Intake
# Age upon Intake
# Breed
# Color
#
#
#
# jbxk-jjnn : Municipal Court Caseload Information FY 2015
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
# Offense Cross Street
# School Zone
# Construction Zone
# Case Closed
# Agency
# Officer Code
#
#
#
# me4f-48mc : 2009-2013: ECAD Residential Energy Audit Data
#
# TCAD or WCAD Property ID (s)
# Auditor
# Company
# Duct System 1 - Type
# Duct System 2 - Type
# Duct System 1 - RValue
# Duct System 2 - RValue
# Duct System 1 - Return Sizing
# Duct System 2 - Return Sizing
# Duct System 1 - % Leakage
# Duct System 2 - % Leakage
# System 1 - Location Air Handler
# System 2 - Location Air Handler
# System 1 - Air Handler Type
# System 2 - Air Handler Type
# System 1 - Age (years)
# System 2 - Age (years)
# System 1 - EER
# System 2 - EER
# System 1 - sqft/ton
# System 2 - sqft/ton
# Water Heater - Fuel Type
# Water Heating - Tank Type
# Toilet Type
# Programmable Thermostat Present
# Window Screen Area Recommended (sqft)
# Furnace - Fuel Type
# Audit Date
# Attic R-Value
# Recommended Additional R-Value
# Year Built
# Bedrooms
# Conditioned (sqft)
# Attic (sqft)
# Home_Type
# As of
# Address
#
#
#
# 92xm-uf99 : Credit Access Businesses
#
# Operating Status
# License Number
# Master File Number
# Licensee
# Operating Name
# Address
# City
# State
# Zip Code
# County
# License Date
# Location
#
#
#
# kidc-knry : Austin Energy Plant Assets
#
# Fiscal Year
# $ Total Plant Assets
#
#
#
# 42ix-g4e3 : AARC Calendar
#
# Date
# Event or Activity
# Location Name
# Location 1
# More information
#
#
#
# 2ds5-jyca : 3-1-1 Call Distribution by Percentage FY 2011
#
# Department
# Percentage
#
#
#
# qzi7-nx8g : Recycle Drop Off Locations
#
# Zone
# Business Name
# Phone
# status
# Oil
# Oil Filter
# Fluids
# Tires
# Batteries
# Newspapers
# Scrap Metal
# Aluminum
# Address
# Zip Code
# latitude
# longitude
#
#
#
# u8uw-t2sm : Municipal Court Caseload Information FY 2011
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
#  Offense Cross Street Name
# School Zone
# Construction Zone
# Case Closed
# Agency Code
# Officer Code
#
#
#
# jmp6-p8e2 : Austin Police Stations
#
# STATION_NAME
# X
# Y
# Location
#
#
#
# 3e38-4hji : Austintexas.gov  - Top 10 Searches
#
# Search Term
# Suggested Resource
# Number of Queries
#
#
#
# qmwp-kjjs : 2012 Bond Program Voter Results
#
# 2012 Bond Program Proposition Number
# Voter Response
# Number of Responses
# Percentage of Responses
#
#
#
# 4us7-37cx : SXSW 2014 Post-Evaluation Survey
#
# Serial
# SID
# Time
# Please identify some venues or activations that were well produced/well executed.
# Did you attend SXSW events and festivities?
# Do you feel the current area of street closures during SXSW Festival is sufficient?  Could the event benefit from more or less closures within the festival vicinity?
# Should festival events and activations be limited to one part of downtown?  Could festivalgoers benefit from all events happening in one area designated for special events?
# Do you feel that outdoor street performance within street closures have a positive or negative influence on crowds in the downtown area?
# Should events be classified by type and hosted in specific areas? (Ex: relaxation lounges, food trailers, grouping music venues by genre)?
# Additional Comments:
# Should the Austin Center for Events issue fewer permits during peak festival seasons such as SXSW?
# More Comments:
# Could festival programming be served by a revamp or second look at the type of music performers playing specific events?  Should performers who have a history of violent or graphic material be scheduled to perform at specific times and locations?
# Do you feel City Resources (Austin Fire, Austin Police, EMS, etc) are currently being distributed evenly among festival events?
# Should the City allow events to take place in lots normally designated for parking?
# Should the City implement limitations on credentials issued and advanced ticket sales based on an event capacity?
# Do you think that services that RSVP to a large number of events via a singular signup provide a positive or negative impact on festivalgoers?
# Comments:
# Concerning the number of loading/unloading zones and times available:
# Should out-of-town event planners be required to incorporate a local event planner to produce their events?
# Should the Texas Alcoholic Beverage Commission limit the amount and hours that alcohol is served at events / venue?
# Should greater or fewer sound limits be required at outdoor events?
# What do you feel is the primary reason people attend downtown festivities during SXSW?
# At the events you attended, do you feel the event producers/venues had adequate security personnel on-site?
# General Comments:
# Location 1
#
#
#
# azsy-zee6 : Austin Animal Center FY14 Outcomes
#
# Animal ID
# Name
# Outcome Date
# Outcome Time
# Outcome Type
# Outcome Subtype
# Animal Type
# Sex upon Outcome
# Age upon Outcome
# Breed
# Color
#
#
#
# 6wtj-zbtb : Austin Code Complaint Cases
#
# CASE_ID
# ADDRESS_LONG
# HOUSE_NUMBER
# STREET_NAME
# CITY
# STATE
# ZIP_CODE
# X
# Y
# OPENED_DATE
# CLOSED_DATE
# DEPARTMENT
# CASE_TYPE
# DESCRIPTION
# CASE_CONTACT
# CASE_MANAGER
# DATE_UPDATED
# LATITUDE
# LONGITUDE
# Location
#
#
#
# md9p-6y8z : Municipal Court Caseload Information FY 2012
#
# Offense Case Type
# Offense Date
# Offense Time
# Offense Charge Description
# Offense Street Name
#  Offense Cross Street Name
# School Zone
# Construction Zone
# Case Closed
# Agency Code
# Officer Code
#
#
#
# ctnk-wvxm : 2-9 to 2-15-14 Austin Animal Center Outcomes
#
# Animal ID
# Outcome Date
# Found Location
# Outcome Type
# Animal Type
# Sex upon Outcome
# Age upon Outcome
# Breed
# Color
#
#
#
# cibe-gpzy : EMS - Patient Contacts by Month
#
# Month Key
# Month-Year
# Total Patient Contacts
# Austin Patient Contacts
# Travis County Patient Contacts
# Other Area Patient Contacts
# Combined COA and TC Patient Contacts
# Total Patient Transports
# Austin Patient Transports
# Travis County Patient Transports
# Other Area Patient Transports
# Combined COA and TC Patient Transports
# Overall Patient Transport Rate
# Austin Patient Transport Rate
# Travis County Patient Transport Rate
# Other Area Patient Transport Rate
# Combined COA and TC Patient Transport Rate
# Patient Transport Rate Target
#
#
#
# dque-zfgd : May 2014 Austin Animal Center Outcomes
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# kwy8-mxxs : June 2014 Austin Animal Center Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# v7ft-5zy3 : January 2014 Austin Animal Center Live Outcome Rates
#
# Type
# Live Outcome Rate
#
#
#
# y6ng-5ymj : ACCD :: Discarded Materials – Fiscal Year 2013
#
# Fiscal Year
# Quarter
# Month
# Category
# Sub-Category
# Material-Source-Donated To
# Weight in Pounds
#
#
#
# krsq-4num : March 2014 Austin Animal Center Outcomes
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# 37zz-93tg : NET Cases
#
# FOLDERRSN
# CASENUMBER
# DATE_OPENED
# DATE_CLOSED
# CASE_TYPE
# INSPECTOR_NAME
# STATUS
# PRIMARY_REPORTED_VIOLATION
# PROPX
# PROPY
# LAST_UPDATE
# ADDRESS
# LONGITUDE
# LATITUDE
# LOCATION
#
#
#
# 37ft-tmhr : Parkranger 01 2015
#
# Date
# Event or Activity
# Location Name
# Time of Event
# Additional Information
#
#
#
# 78b7-3v9t : Austin Public Library display ads
#
# Image
# Title
# Display Start
# Display End
#
#
#
# drnt-j5qy : Sep 2013 Austin Animal Center Outcome Count
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# drs6-93kf : AFD Fire Incidents 2013 Thru July20 2015
#
# MasterIncidentNumber
# CalendarYear
# Month
# DayOfMonth
# Call_Type
# Problem
# Battalion
# Jurisdiction
# ResponseArea
# PriorityDescription
# Response Status
# Responding Unit
# Location 1
#
#
#
# krg6-2bs5 : Collection Size and Cardholders at the Austin Public Library
#
# Date
# Collection Size
# Registered Library Card Holders
#
#
#
# nqv2-nbrj : Aug 2013 Austin Animal Center Outcome Count
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# 4sv9-5zm8 : Aug 2013 Austin Animal Center Live Outcome Rate
#
# Animal Type
# Live Outcome Rate
#
#
#
# rtwz-6ypq : February 2014 Austin Animal Center Outcomes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# vs6n-chuq : 2-16 to 2-22-14 Austin Animal Center Outcomes
#
# Animal ID
# Outcome Date
# Found Location
# Outcome Type
# Animal Type
# Sex upon Outcome
# Age upon Outcome
# Breed
# Color
#
#
#
# 39mp-u93d : Capital Improvement Projects Managed by Public Works (August 2015)
#
# Location
# Project ID
# Project Name
# Description
# Construction Cost Estimate
# Current Phase
# Phase By Nov 1
# Contact
# Email
#
#
#
# hcnj-rei3 : 2014 Housing Market Analysis Data by Zip Code
#
# Zip Code
# Population below poverty level
# Median household income
# Non-White, Non-Hispanic or Latino
# Hispanic or Latino, of any race
# Population with disability
# Unemployment
# Large households (5+ members)
# Homes affordable to people earning less than $50,000
# Rentals affordable to people earning less than $25,000
# Rent-restricted units
# Housing Choice Voucher holders
# Median rent
# Median home value
# Percentage of rental units in poor condition
# Percent change in number of housing units, 2000-2012
# Owner units affordable to average retail/service worker
# Rental units affordable to average retail/service worker
# Rental units affordable to average artist
# Owner units affordable to average artist
# Rental units affordable to average teacher
# Owner units affordable to average teacher
# Rental units affordable to average tech worker
# Owner units affordable to average tech worker
# Change in percentage of population below poverty, 2000-2012
# Change in median rent, 2000-2012
# Change in median home value, 2000-2012
# Percentage of homes within 1/4-mi of transit stop
# Average monthly transportation cost
# Percentage of housing and transportation costs that is transportation-related
#
#
#
# 6m7k-g59q : August 2014 Austin Animal Center Live Outcome Rates
#
# Animal Type
# Live Outcome Rate
#
#
#
# da96-d4bx : April 2014 Austin Animal Center Live Outcomes
#
# Animal Type
# Live Outcome Rate
#
#
#
# 8jjf-bejx : September 2014 Austin Animal Center Intake Data
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# 9ejy-j7t5 : February 2014 Austin Animal Center Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# pzre-m4ee : May 2014 Austin Animal Center Live Outcome Rates
#
# Animal Type
# Live Outcome Rate
#
#
#
# bw6v-aead : July 2014 Austin Animal Center Outcomes
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# ba4t-mrbm : Sep 2013 Austin Animal Center Intake Count
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# cqdh-farx : Traffic Count Study Area
#
# 24 HOUR VOLUME COUNT LOCATIONS
# NB TOTAL
# SB TOTAL
# EB TOTAL
#  WB TOTOAL
# TOTAL VOLUME
# DATE
#
#
#
# 55ji-8nqx : Austintexas.gov - Social Media Network Referrals
#
# Social Network Name
# Sessions
# Pageviews
# Average Session Duration
# Pages / Session
#
#
#
# sbi4-ahzs : ​​​Austin Water - Energy Consumption for All Plants
#
# Year
# Month
# Plant
# Type of Plant
# kWh per MG Treated
#
#
#
# kpdv-fdxg : July 2014 Austin Animal Center Monthly Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# 86z9-i27i : Repeat Offender Registrations
#
# FOLDERNUMBER
# FOLDERSUBTYPE
# STATUS
# ISSUEDATE
# EXPIRYDATE
# PROPERTYNAME
# FOLDERNAME
# Location 1
#
#
#
# dcfk-vk6w : Google Analytics Sessions on Austintexas.gov
#
# Date
# Sessions
#
#
#
# 2e3p-8zzy : ACCD :: Discarded Materials – Fiscal Year 2014
#
# Fiscal Year
# Quarter
# Month
# Category
# Sub-Category
# Material-Source-Donated To
# Weight in Pounds
#
#
#
# 8yfa-b3bq : Austintexas.gov  - Top 50 Pages By Pageviews
#
# Page
# Pageviews
# Unique Pageviews
# Avg. Time on Page
# Entrances
# Bounce Rate
# % Exit
#
#
#
# vzty-yezt : Sep 2013 Austin Animal Center Live Outcome Rate
#
# Animal Type
# Live Outcome Rate
#
#
#
# up99-pfez : January 2014 Austin Animal Center Outcomes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# cr83-wy4q : Wireless Usage at Austin Public Library
#
# Date
# Faulk Central Library
# Carver Branch
# Cepeda Branch
# Hampton Branch at Oak Hill
# Howson Branch
# Little Walnut Creek Branch
# Milwood Branch
# Manchaca Road Branch
# North Village Branch
# Old Quarry Branch
# Pleasant Hill Branch
# Recycled Reads Bookstore
# Ruiz Branch
# Southeast Branch
# St. John Branch
# Spicewood Springs Branch
# Terrazas Branch
# Twin Oaks Branch
# University Hills Branch
# Willie Mae Kirk Branch
# Windsor Park Branch
# Yarborough Branch
#
#
#
# cu49-7a5a : April 2014 Austin Animal Center Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# 7kz2-qyez : March 2014 Austin Animal Center Live Outcome Rates
#
# Animal Type
# Live Outcome Rate
#
#
#
# 8qty-vat2 : Open Data Initiative Progress Report - Participation Sprint
#
# dept
# liaison
# inventory
# plans
# publication
#
#
#
# k4zx-bu88 : January 2014 Austin Animal Center Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# tb3x-mddn : June 2014 Austin Animal Center Live Outcome Rates
#
# Animal Type
# Percentage
#
#
#
# 7xxy-upkf : July 2014 Austin Animal Center Live Outcome Rates
#
# Animal Type
# Percentage
#
#
#
# t9gx-rxwg : Water Quality Sampling Locations
#
# SampleSiteNo
# SiteName
# Watershed
# SiteType
# Location
# Number of Visits
# Number of Data Points
# First SampleDate
# Most Recent SampleDate
# EII Site
# ALI Site
#
#
#
# 7it9-7pjx : December 2013 Live Outcomes
#
# Animal Type
# Live Outcome Rate
#
#
#
# fr2x-kbjs : Repeat Offender List
#
# Property Name
# Type of Property (Multi-family, Single-family)
# Address
# # of Buildings
# # of Units
# License Number
# Date Registration Mailed
# Status
# Additional Enforcement Action
#
#
#
# aqaz-cxjw : Social Media - Top Commenters
#
# Commenter
# Mentions
# Direct Messages
# Wall Comments
# Photo Comments
# Number of Followers
# Platform
# General Interest Area
#
#
#
# ykzu-pxxq : FY13 Day Labor Placements
#
# Date
# Day of Week
# Log Out 6-6:59am
# Log Out 7-7:59am
# Log Out 8-8:59am
# Log Out 9-9:59am
# Log Out 10-10:59am
# Log Out 11-11:59am
# Log Out 12-12:59pm
# Log Out 1-1:59pm
# Total Signed Out
# Total Contractors
# Total Signed In
# Stayed Until Close
# Weather / Holiday
#
#
#
# 8pvq-5pcm : November Austin Animal Center Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# 74y5-wjkf : Oct 2013 Austin Animal Center Live Outcome Rate
#
# Type
# TLOR
#
#
#
# 567b-4d24 : Austin Finance Online eCheckbook Column Definitions
#
# eCheckbook Column Name
# Definition
# Notes
#
#
#
# ydem-x7j5 : Aug 2013 Austin Animal Center Intake Count
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# 8uvp-rwpt : Utlity Contact Center Call Distribution For FY2011
#
# Type
# Percentage
#
#
#
# db24-fcaw : 2-16 to 2-22-14 Austin Animal Center Intakes
#
# Animal ID
# Intake Date
# Found Location
# Intake Type
# Intake Condition
# Animal Type
# Sex upon Intake
# Age upon Intake
# Breed
# Color
#
#
#
# tsum-aa7v : FY14 Day Labor Placements
#
# Date
# Day of Week
# Log Out 6-6:59am
# Log Out 7-7:59am
# Log Out 8-8:59am
# Log Out 9-9:59am
# Log Out 10-10:59am
# Log Out 11-11:59am
# Log Out 12-12:59pm
# Log Out 1-1:59pm
# Total Signed Out
# Total Contractors
# Total Signed In
# Stayed Until Close
# Weather / Holiday
#
#
#
# 8ruh-ty5d : November Austin Animal Center Live Outcome Rate
#
# Animal Type
# Live Outcome Rate
#
#
#
# yj9d-ajag : Utility Contact Center Average Speed For Answering Calls
#
# Fiscal Year
# Seconds
#
#
#
# 2k49-v9jb : NET Complaint Cases (Dev Version)
#
# Folder ID
# Case Number
# Date Opened
# Property Type
# Address
# Case Status
# Primary Reported Violation
# Prop X
# Prop Y
# Latitude
# Longitude
# Last Updated
# inspector_name
#
#
#
# x64f-gjq4 : 2015 Spring Festival Applications
#
# Event/Venue Name
# Start Date
# End Date
# SXSW
# Location 1
# COMMENTS
#
#
#
# ps5c-8d86 : Oct 2013 Austin Animal Center Intake Count
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# eg8t-399m : Oct 2013 Austin Animal Center Outcome Count
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# tc36-hn4j : Austin Public Library Locations
#
# Term ID
# Name
# Address
# Latitude / Longitude
# Phone
# District
# Note
# Open Hours
# Description
#
#
#
# ej42-f7za : City of Austin Social Media Analysis
#
# Account
# Type
# External Link
# Owner Department
# Total Activity
# Outgoing Activity
# Incoming Activity
# Incoming Percentage
#
#
#
# yfqx-zefp : EMS - Travis County ILA - Emergency Response - On Time Rate - City and County
#
# Month
# Incident Count
# Goal Met Count
# Goal Met Percentage
# Target Percentage
# Average
#
#
#
# m9jn-qzir : FY11 Day Labor Placements
#
# Date
# Day of Week
# Log Out 6-6:59am
# Log Out 7-7:59am
# Log Out 8-8:59am
# Log Out 9-9:59am
# Log Out 10-10:59am
# Log Out 11-11:59am
# Log Out 12-12:59pm
# Log Out 1-1:59pm
# Total Signed Out
# Total Contractors
# Total Signed In
# Stayed Until Close
# Weather / Holiday
#
#
#
# vwcu-h3qu : Utility Contact Center Calls Answered
#
# Fiscal Year
# Calls Answered
#
#
#
# 876d-75ye : Austin Parks and Recreation Golf Clinics
#
# Date
# Event or Activity
# Location Name
# More information
# Start Time
#
#
#
# sute-ma6h : Austin GO VIews From Different Browsers
#
# Browser
# Unique Pageviews
#
#
#
# c9gq-k8de : FY 2016 Proposed Operating Budget Expenditures – Line Item Detail
#
# PROPOSED_FISCAL_YEAR
# DEPT_ROLLUP
# DEPT_ROLLUP_NAME
# DEPARTMENT_CODE
# DEPARTMENT_NAME
# FUND_CODE
# FUND_NAME
# PROGRAM_CODE
# PROGRAM_NAME
# ACTIVITY_CODE
# ACTIVITY_NAME
# UNIT_CODE
# UNIT_NAME
# EXPENSE_CODE
# EXPENSE_NAME
# PROPOSED_BUDGET
#
#
#
# us2y-viyp : Grow Green Participant Locations
#
# Name
# Phone
# Address
# Zip Code
#
#
#
# rd5n-3pmq : Golf Location
#
# GOLF COURSES
# Location 1
#
#
#
# pdfd-8tju : Battery Drop Off Locations
#
# Business
# Zip Code
# Phone #
# Location
#
#
#
# p9ma-z6y9 : ACCD :: Event Listings – Current Calendar Year
#
# Arrive Date
# Depart Date
# Location
# Event Name
# Attendance
# Phone Number
# Website
#
#
#
# itfg-ism7 : June 2014 Austin Animal Center Outcomes
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# 692b-xsit : Concentrations of Protected Classes from Analysis of Impediments
#
# GEOID
# Census Tract
# County
# RCAP or ECAP
# Majority-Minority
# Hispanic Concentration
# Black/African American Concentration
# Asian Concentration
# Poverty Concentration
# Disabled Concentration
# Linguistically Isolated Concentration
# Foreign-Born Concentration
#
#
#
# rbfq-6fgu : September 2014 Austin Animal Center Live Outcome Rate Data
#
# Animal Type
# Live Outcome Rate
#
#
#
# gyhm-zak6 : EMS Patient Transport Rate  City And County Combined
#
# Month-Year
# Combined COA and TC Patient Contacts
# Combined COA and TC Patient Transports
# Combined COA and TC Patient Transport Rate
# Patient Transport Rate Target
#
#
#
# wxwa-v96x : EMS Incidents City And County Stratified
#
# Month-Year
# Austin Incidents
# Travis County Incidents
#
#
#
# 7i7c-96kx : EMS Responses In City And County Combined
#
# Month-Year
# Total Austin Responses
# Total Travis County Responses
# Combined City and County Responses
#
#
#
# sxk7-7k6z : Austin Water - Residential Water Consumption
#
# Year Month
# Postal Code
# Customer Class
# Total Gallons
#
#
#
# ndjh-4ukq : EMS Responses By City Units Into County
#
# Month-Year
# Total Travis County Responses
# COA Unit Responses into TC
# Percent TC Responses by COA
#
#
#
# ewqz-mrzs : Bond Ratings
#
# Description of Debt
# Fiscal Year Ended
# Fitch, Inc.
# Moody's Investors Service, Inc.
# Standard and Poor's
#
#
#
# ekzc-6qg9 : Heat Rate
#
# Fiscal Year
# System annual average heat rate (BTU/net kWh)
#
#
#
# w8rr-4qky : City of Austin Lawsuit Settlements
#
# Case Name
# Incident Date
# Department
# Disposition
# Amount
# Case Type
#
#
#
# 2b2e-w4kf : Budget Billing
#
# Fiscal Year
# Month and Year
# calendar date UTC format
# calendar year
# calendar month
# Billed Levelized Accounts Per Month
# Average Levelized Bill Amount
#
#
#
# 6v99-vnq3 : Austin Water - Wastewater Service Connection Count By Zip Code
#
# Postal Code
# Customer Class
# Service Connections
#
#
#
# uizf-mcbc : Austin Water - Water Service Connection Count By Zip Code
#
# Postal Code
# Customer Class
# Service Connections
#
#
#
# wfm8-s7zc : Austin Water - Gallons of Water Pumped per Capita
#
# FiscalYear
# Pumpage
# Water Service Population
# Pumpage per capita per day
#
#
#
# vuwy-s6qv : Austin Water - Gallons of Wastewater Treated
#
# Year
# Month
# Plant
# Type of Water
# MG Treated
#
#
#
# 5h9c-wmds : Austin Water - Commercial Water Consumption
#
# Year Month
# Postal Code
# Customer Class
# Total Gallons
#
#
#
# erps-465e : Austin Energy Operating Budget
#
# Fiscal Year
# Total Available Funds
# Total Requirements
# Excess/Deficiency
#
#
#
# 6zan-sbz2 : Bad Debt Expense
#
# Fiscal Year
# Revenue
# Bad Debt Expense
# Percentage
#
#
#
# jhra-82n2 : ARR Household Hazardous Waste Monthly Materials Collection Weight Report
#
# Material
# Oct-14
# Nov-14
# Dec-14
# Jan-15
# Feb-15
# Mar-15
# Apr-15
# May-15
# Jun-15
# Jul-15
# Aug-15
# Sep-15
#
#
#
# hetr-8wqd : Carbon Intensity
#
# pounds of CO2-eq/kWh
# calendar year
#
#
#
# 84hw-edzm : EMS On- Time Rate  Travis County
#
# Month-Year
# Travis County Incidents
# Travis County On-Time Compliance
# Target On-Time Compliance
#
#
#
# qf6q-sssu : EMS Responses Stratified By City And County
#
# Month-Year
# Total Austin Responses
# Total Travis County Responses
#
#
#
# e2k6-2zqs : EMS   On- Time Rate  City Of Austin
#
# Month-Year
# Austin Incidents
# Austin On-Time Compliance
# Target On-Time Compliance
#
#
#
# pbam-er2r : Austin Water - List of Active Liquid Waste Haulers
#
# BUSINESS_NAME
# ADDRESS_1
# ADDRESS_2
# CITY
# ZIP
# PHONE
# PHONE_EXT
# Austin Water List of Active Liquid Waste Haulers
#
#
#
# cje8-pznp : ARR Household Hazardous Waste Totals Comparison of Fiscal Years 2010-2015
#
# Description/ Fiscal Year
# Oct-14
# Nov-14
# Dec-14
# Jan-15
# Feb-15
# Mar-15
# Apr-15
# May-15
# Jun-15
# Jul-15
# Aug-15
# Sep-15
#
#
#
# c7z7-zp6h : 2015-08-15 Austin Sustainability Indicators
#
# Date
# Chart date
# Topic Area
# Key Performance Indicator
# Value
#
#
#
# cvnz-fq2z : Bike Fix It
#
# Recreation Centers
# Zip Code
# Phone Number
# Location 1
#
#
#
# a2zj-3chk : Cemeteries Location
#
# CITY CEMETERIES
# Designation
# Location 1
#
#
#
# 9w5t-cuk2 : Austin Animal Center FY15 Q1 Intakes
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# wtyt-mpzf : April 2014 Austin Animal Center Outcomes
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# 67kt-ykxh : Airport Monthly Operational Report
#
# Month
# Domestic Enplaned Passengers: Revenue
# Domestic Deplaned Passengers: Revenue
# International Enplaned Passengers: Revenue
# International Deplaned Passengers: Revenue
# Domestic Enplaned Passengers: Non-Revenue
# Domestic Deplaned Passengers: Non-Revenue
# International Enplaned Passengers: Non-Revenue
# International Deplaned Passengers: Non-Revenue
# International Enplaned Pre-Cleared Passengers: Revenue
# International Deplaned Pre-Cleared Passengers: Revenue
# International Enplaned Pre-Cleared Passengers: Non-Revenue
# International Deplaned Pre-Cleared Passengers: Non-Revenue
# Total Passengers
# Air Carrier Operations
# Commuter and Air Taxi Operations
# Military Operations
# General Aviation:  Itinerant Operations
# General Aviation: Local Operations
# General Aviation: Total Operations
# Total Operations
# Domestic Enplaned Mail
# Domestic Deplaned Mail
# International Enplaned Mail
# International Deplaned Mail
# Mail Totals
# Domestic Enplaned Cargo
# Domestic Deplaned Cargo
# International Enplaned Cargo
# International Deplaned Cargo
# Cargo Totals
# Domestic Enplaned Belly Freight
# Domestic Deplaned Belly Freight
# International Enplaned Belly Freight
# International Deplaned Belly Freight
# Belly Freight Totals
# Cargo Totals (Cargo + Mail + Belly Freight)
# Landing Totals
# Weight Totals
#
#
#
# xp28-5kft : 2014 Austin Digital Assessment Individual Responses
#
# Adults in Household
# Kids
# Home Internet Access
# TV
# Cable
# Satellite
# Game Console
# Desktop
# Laptop
# Homephone
# Cellphone
# Tablet
# Internet-connected Game Console
# Smartphone
# Use the Internet
# Years Using the Internet
# teachpar
# teachsib
# teachspouse
# teachchild
# teachrel
# teachcourse
# teachfriend
# teachteacher
# teachlibrarian
# teachco
# myself
# teachother
# teachtext
# helpInt
# upgrade
# awareTW
# awareGrande
# awareATT
# awareGoogle
# Q3M_1 Capable of uploading content to website
# Q3M_2 Capable of blocking spam
# Q3M_3 Capable of adjusting privacy settings
# Q3M_4 Capable of bookmarking or adding favorites
# Q3M_5 Capable of comparing sites to check accuracy of information
# Q3M_6 Capable of creating and managing a social networking profile
# Q3M_7 Capable of creating and managing a personal website
# Q3M_8 Capable of recognizing a phishing request
# Q3M_9 Capable of making my own content
# Q3N_1 Access the Internet at home
# Q3N_2 Access the Internet at work
# Q3N_3 Access the Internet at school/university
# Q3N_4 Access the Internet at Austin Public Library
# Q3N_5 Access the Internet at coffee shop or private business
# Q3N_6  Access the Internet at friend/family member home
# Q3N_7 Access the Internet at community center or public place
# Q3N_8 Access the Internet at COA Free Public WiFi
# Q4A_1 Access the Internet on smartphone
# Q4A_2 Access the Internet on tablet
# Q4A_3 Access the Internet on personal computer
# Q4A_4 Access the Internet on computer at city library/lab
# Q4A_5 Access the Internet on a game console
# Q4B_1 Read email on smartphone
# Q4B_2 Read email on tablet
# Q4B_3 Read email on personal computer
# Q4B_4  Read email on computer at city library/lab
# Q4B_5 Read email on a game console
# Q4C_1 Play online games on smartphone
# Q4C_2 Play online games on tablet
# Q4C_3 Play online games on personal computer
# Q4C_4 Play online games on computer at city library/lab
# Q4C_5 Play online games on a game console
# Q4D_1 Buy a product online on smartphone
# Q4D_2 Buy a product online on tablet
# Q4D_3 Buy a product online on personal computer
# Q4D_4  Buy a product online on computer at city library/lab
# Q4D_5 Buy a product online on a game console
# Q4E_1 Pay bills or online banking on smartphone
# Q4E_2 Pay bills or online banking on tablet
# Q4E_3 Pay bills or online banking on personal computer
# Q4E_4 Pay bills or online banking on computer at city library/lab
# Q4E_5 Pay bills or online banking on a game console
# Q4F_1 Create/post original media on smartphone
# Q4F_2 Create/post original media on tablet
# Q4F_3 Create/post original media on personal computer
# Q4F_4 Create/post original media on computer at city library/lab
# Q4F_5 Create/post original media on a game console
# Q4G_1 Listen to music/radio on smartphone
# Q4G_2 Listen to music/radio on tablet
# Q4G_3 Listen to music/radio on personal computer
# Q4G_4 Listen to music/radio on computer at city library/lab
# Q4G_5 Listen to music/radio on a game console
# Q4H_1 Participate in discussion forum on smartphone
# Q4H_2 Participate in discussion forum on tablet
# Q4H_3 Participate in discussion forum on personal computer
# Q4H_4 Participate in discussion forum on computer at city library/lab
# Q4H_5 Participate in discussion forum on a game console
# Q4I_1 Use social network on smartphone
# Q4I_2 Use social network on tablet
# Q4I_3 Use social network on personal computer
# Q4I_4 Use social network on computer at city library/lab
# Q4I_5 Use social network on a game console
# Q4J_1 Read e-books/online magazine/newspaper on smartphone
# Q4J_2 Read e-books/online magazine/newspaper on tablet
# Q4J_3 Read e-books/online magazine/newspaper on personal computer
# Q4J_4 Read e-books/online magazine/newspaper on computer at city library/lab
# Q4J_5 Read e-books/online magazine/newspaper on a game console
# Q4K_1 Comment on TV content on smartphone
# Q4K_2 Comment on TV content on tablet
# Q4K_3 Comment on TV content on personal computer
# Q4K_4 Comment on TV content on computer at city library/lab
# Q4K_5 Comment on TV content on a game console
# Q4L_1 Pay utilities/ check city info on smartphone
# Q4L_2 Pay utilities/ check city info on tablet
# Q4L_3 Pay utilities/ check city info on personal computer
# Q4L_4 Pay utilities/ check city info on computer at city library/lab
# Q4L_5 Pay utilities/ check city info on a game console
# Q3B
# Q3C_1 Too expensive
# Q3C_2 Safety/privacy concerns
# Q3C_3 Not enough time
# Q3C_4 Not interested
# Q3C_5 Someone uses Internet for me
# Q3C_6 No one to teach me
# Q3C_7 do not speak English
# Q3C_8 Too difficult
# Q3D Interested in free training
# Q3E_1 Want training on social media
# Q3E_2 Want training on email
# Q3E_3 Want training on job searching/online applications
# Q3E_4 Want training on software
# Q3E_5 Want training on creating content
# Q3F Subscribe for home broadband at affordable price
# Q3G Too expensive for monthly Internet
# Q5A_1 View entertainment on cable or satellite TV
# Q5A_2 View entertainment on a device to stream media
# Q5A_3 View entertainment on DVD player
# Q5A_4 View entertainment on Hulu
# Q5A_5 View entertainment on Netflix
# Q5A_6 View entertainment on Amazon Prime
# Q5B_1_1 Get information about Neighborhood
# Q5B_1_2 Get information about Neighborhood
# Q5B_1_3 Get information about Neighborhood
# Q5B_1_4 Get information about Neighborhood
# Q5B_1_5 Get information about Neighborhood
# Q5B_1_6 Get information about Neighborhood
# Q5B_1_7 Get information about Neighborhood
# Q5B_1_8 Get information about Neighborhood
# Q5B_2_1 Get information about Austin
# Q5B_2_2 Get information about Austin
# Q5B_2_3 Get information about Austin
# Q5B_2_4 Get information about Austin
# Q5B_2_5 Get information about Austin
# Q5B_2_6 Get information about Austin
# Q5B_2_7 Get information about Austin
# Q5B_2_8 Get information about Austin
# Q5B_3_1 Get information about Texas
# Q5B_3_2 Get information about Texas
# Q5B_3_3 Get information about Texas
# Q5B_3_4 Get information about Texas
# Q5B_3_5 Get information about Texas
# Q5B_3_6 Get information about Texas
# Q5B_3_7 Get information about Texas
# Q5B_3_8 Get information about Texas
# Q5B_4_1 Get information about USA
# Q5B_4_2 Get information about USA
# Q5B_4_3 Get information about USA
# Q5B_4_4 Get information about USA
# Q5B_4_5 Get information about USA
# Q5B_4_6 Get information about USA
# Q5B_4_7 Get information about USA
# Q5B_4_8 Get information about USA
# Q5B_5_1 Get information about Other countries
# Q5B_5_2 Get information about Other countries
# Q5B_5_3 Get information about Other countries
# Q5B_5_4 Get information about Other countries
# Q5B_5_5 Get information about Other countries
# ...
# Q5F_1 High speed internet improves Home Entertainment
# Q5F_2 High speed internet improves Starting Businesses
# Q5F_3 High speed internet improves Innovation
# Q5F_4 High speed internet improves Working from home
# Q5F_5 High speed internet improves Online learning/education
# Q5F_6 High speed internet improves Internet pricing options
# Q8A_1 Know a nurse
# Q8A_2 Know a farmer
# Q8A_3 Know a lawyer
# Q8A_4 Know a middle school teacher
# Q8A_5 full-time babysitter
# Q8A_6 Know a janitor
# Q8A_7 Know a personnel manager
# Q8A_8 Know a hair dresser
# Q8A_9 Know a bookkeeper
# Q8A_10 Know a production manager
# Q8A_11 Know an operator in a factory
# Q8A_12 Know a computer programmer
# Q8A_13 Know a taxi driver
# Q8A_14 Know a professor
# Q8A_15 Know a policeman
# Q8A_16  Know a CEO of large company
# Q8B_1 Employment status
# Q8B_2 Employment status
# Q8B_3 Employment status
# Q8B_4 Employment status
# Q8B_5 Employment status
# Q8B_6
# Q8B_7
# Q8B_8
# Q8B_9
# Q8B_9_TEXT
# Q8B_10
# Q8C_1 Type of work
# Q8C_2 Type of work
# Q8C_3 Type of work
# Q8C_4 Type of work
# Q8C_5 Type of work
# Q8C_6 Type of work
# Q8C_7 Type of work
# Q8C_8 Type of work
# Q8D
# Q8E_1 Info about job
# Q8E_2 Info about job
# Q8E_3 Info about job
# Q8E_4 Info about job
# Q8E_5 Info about job
# Q8E_8 Info about job
# Q8E_7 Info about job
# Q8E_6 Info about job
# Q8E_9 Info about job
# Q8E_9_TEXT
# Q8F_1 Current job from personal contacts
# Q8F_2 Current job from personal contacts
# Q8F_3 Current job from personal contacts
# Q8F_4 Current job from personal contacts
# Q8F_5 Current job from personal contacts
# Q8F_6 Current job from personal contacts
# Q8F_6_TEXT Current job from personal contacts
# Q8G How often do you work from home
# Q8H Remote access
# Q8I Self-employed/Small business owner
# Q8A High-tech sector
# Q8B Cultural Industry sector
# Q8C Years in operation
# Q8D_A Number of employees
# Q8E_1_A Business has A website
# Q8E_2_A Business has A blog
# Q8E_3_A Business has Facebook presence
# Q8E_4_A Business has Twitter presence
# Q8E_5_A Business has A mobile app
# Q8E_6_A Business has Presence on other social media platforms
# Q8F_1_A Business uses social media for Advertising, marketing and promotion
# Q8F_2_A Business uses social media for Building professional networks
# Q8F_3_A Business uses social media for Crowdfunding
# Q8F_4_A Business uses social media for Crowdsourcing
# Q8F_5_A Business uses social media for Tracking and analyzing social media
# Q8F_6_A Business uses social media for Using social media management tools (eg Hootsuite)
# Q8F_7 Business uses social media for Recruiting Employees
# Sex
# Hispanic
# White
# Black or African American
# Asian or Pacific Island
# American Indian, Eskimo, or Alaska Native
# Other
# Other_TEXT
# Disabled
# Fluent English
# Fluent Spanish
# BirthYr
# Years in Austin
# Relationship status
# Relationship Other
# Education (self)
# Education (mother)
# Education (father)
# Income
# Born in the US (Self)
# Born outside US (self)
# Born Unsure (Self)
# Born in the US (Mother)
# Born outside US (Mother)
# Born Unsure (Mother)
# Born in the US (Father)
# Born outside US (Father)
# Born Unsure (Father)
# Born in the US (Grandparents)
# Born outside US (Grandparents)
# Born Unsure (Grandparents)
# Agenew1
# weight6
# Location 1
#
#
#
# 9e5g-zqyt : Plus 1 Funding Source
#
# Funding Source
# FY 2006
# FY 2007
# FY 2008
# FY 2009
# FY 2010
# FY 2011
# FY 2012
# FY 2013
# FY 2014
# FY 2015
#
#
#
# f4c7-5ivu : Kirwan Institute Opportunity Map Data
#
# GeoID
# Census Geography
# Housing & Environment Index
# Education Index
# Economic & Mobility Index
# Comprehensive Opportunity Index
# Housing & Environment Score
# Education Score
# Economic & Mobility Score
# Comprehensive Opportunity Score
#
#
#
# 5j2i-tq4k : COA FUEL BY DEPARTMENT
#
# DEPT_NO
# DEPARTMENT
# VEHICLE_COUNT
# MAINT_DOLLARS
# FUEL_QTY
# AVG_MILES_PER_VEHICLE
# TOTAL_MILES
#
#
#
# wzdb-642v : CY14 AFD Standard Of Coverage By RAP
#
# Response Area
# Number of Emergency Incidents with Valid Data
# Number of Arrivals within 8 minutes
# Percent of Arrivals within 8 Minutes
# First-In Department AFD
# First-In Department ESD
# 90th Percentile  Total Response Time (Call Receipt-to-1st Arrive)
#
#
#
# nw7z-k49b : EMS Responses By County Units Into City
#
# Month-Year
# Total Travis County Responses
# TC Unit Responses into COA
# Percent COA Responses by TC
#
#
#
# w635-mmjr : EOC Activations - City Open Data   HSEM
#
# EOC Activation Start Date
# EOC Activation End Date
# Hazard
# Harzard Details
#
#
#
# 3maj-7ecz : Travis County Community-wide Greenhouse Gas Emissions Inventory
#
# Year
# Materials and Waste Management
# Transportation & Mobile Sources
# Water & Wastewater
# Process & Fugitive Emissions
# Industrial Electricity & Natural Gas
# Residential Electricity & Natural Gas
# Commercial Electricity & Natural Gas
#
#
#
# mg7a-uqpj : EMS Percent County Responses By City Units
#
# Month-Year
# Total Travis County Responses
# COA Unit Responses into TC
# Percent TC Responses by COA
#
#
#
# 9xdm-yhmb : Austin Energy Customer Data by Customer Class
#
# Customer Class
# Fiscal Year
# Number of Customers
# Revenue
# Percentage of Revenue
# Cents per kWh
# Percentage of MWh
#
#
#
# jmuq-5usm : COA INFO BY CLASS
#
# MANAGEMENT_CLASS
# CLASS_DESC
# VEHICLE_COUNT
# MAINT_DOLLARS
# FUEL_QTY
# AVG_MILES_PER_VEHICLE
# TOTAL_MILES
#
#
#
# f6gm-a8j6 : COA ODP FUELBYTYPE
#
# FISC_YR
# PROPANE
# E10_UNLEADED
# DIESEL
# BIODIESEL
# CNG
# E85
#
#
#
# xf72-sbj4 : Austin Digital Assessment - Aggregated Responses by Geography
#
# ZIPCODE/COUNCIL DISTRICT
# INTERNET USERS
# INTERNET NON-USERS
# HOME INTERNET ACCESS
# SMARTPHONE USAGE RATES
# PC (LAPTOP AND/OR DESKTOP) OWNERSHIP
# NON-USERS - Reasons for not using the internet: EXPENSE
# NON-USERS - Reasons for not using the internet: PRIVACY CONCERNS
# NON-USERS - Reasons for not using the internet: NOT INTERESTED
# NON-USERS - Reasons for not using the internet: NO ONE TO TEACH ME
# NON-USERS - Reasons for not using the internet: NOT ENOUGH TIME
# NON-USERS - Reasons for not using the internet: TOO DIFFICULT
# NON-USERS - Reasons for not using the internet: SOMEONE USES INTERNET FOR ME
# NON-USERS - Reasons for not using the internet: DO NOT SPEAK ENGLISH WELL ENOUGH
# NON-USERS - Help with Technology: I know enough to go online on my own
# NON-USERS - Help with Technology: I would need someone to help me
# NON-USERS - Help with Technology: I would not want to start using the Internet
# NON-USERS - Interested in Free Training: YES
#
#
#
# fytz-zuei : Event Waivers
#
# Start Time
# Title
# Waiver (1)
# Waiver (2)
#
#
#
# e2a3-3mi6 : September 2014 Austin Animal Center Outcome Data
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# acyh-8suc : Municipal Carbon Footprint
#
# Year
# Power Generation & Delivery
# Wastewater Treatment
# FM 812 Landfill
# Natural Gas Use
# Diesel Use for Back-up Generators
# Transportation Fuel Use
# Refrigerant Use
# Electricity Use from Non-AE Sources
# Chilled Water Energy
#
#
#
# 3tiy-6kg3 : Claim Settlements for City of Austin
#
# Claim Name
# Incident Date
# Department
# Location of Incident (if applicable)
# Amount
# Category
# Disposition Type
#
#
#
# nw8s-p3bj : Digital Inclusion Organization Inventory
#
# Program
# Branch/Lab
# Status
# # of Machines
# On-Site Trainer
# Sub Training Programs Offered
# Public Access?
# Street Address
# County
# Council District
# Our Contact
# Our Contact Email
# Phone
# Hours
# Trainnig Hours
# Paid or Volunteer Trainer
# Special Training
# Non-English Speaking Languages
# Disabled Accessibility
# Last Updated
# Location
#
#
#
# x4vz-3xdy : Airport Annual Performance Measures
#
# Reporting Year
# Terminal Electricity Use: KWH
# Terminal Natural Gas Use: CCF
# Terminal Water Use: Gallons
# Terminal Wastewater Use: Gallons
# Campus Electrity Use: KWH
# Campus Natural Gas Use: CCF
# Campus Water Use: Gallons
# Campus Reclaimed Water Use: Gallons
# Campus Waste Water Use: Gallons
# Percentage Green Choice Electricity
# De-Icing: Airport Operations: Gallons
# De-icing: Pavement/Ground Operations: Gallons
# De-Icing: Pavement/Ground Operations: Lbs
# De-Icing: Pond Discharges to Waste Water: Gallons
# De-Icer Treated at Waste Water Plant: Lbs
# Terminal Waste to Landfill: Tons
# Terminal Waste Recycled: Tons
# Brush Composting: Tons
# Light Bulb Recycling: Lbs
# Light Bulb Recycling: Units
# Alkaline and Rechargeable Batteries: Lbs
# Electronic Waste: Lbs
# Vehicle Batteries Recycled
# Tires Recycled
# Oil Recycled: Gallons
# Demolition Recycling: Tons
# Gasoline Use: Gallons
# Ethanol (E85) Use: Gallons
# Diesel Use: Gallons
# Propane Use: Gallons
# CNG: Gallons
# Alternative Fuel Mowers
# Alternative Fuel Off-Road Units
# Alternative Fuel On-Road Units
# Carbon Footprint: Metric Tons
# Carbon Footprint Reduction
# Annual Aircraft Operations
# FOD (Debris) Removed from Apron: Lbs
# Wildlife/Bird Strikes
# Deficiencies Noted During Daily 139 Inspections (Internal Operations)
# Deficiencies Noted During  139 Inspections (External Inspectors)
# AOA Warnings Issued
# Percent Security Responses within Established Time
# Security Violations Issued
# Average Morning Wait Time at Security Checkpoints: Minutes
# Average Afternoon Wait Time at Security Checkpoints: Minutes
# Number of ARFF Responses
# Average Repair Time Call to Completion: Minutes
# EPAX per Gate Utilized
# Enplanements: Change over Prior Period
# Gate Utilization (Turns per Gate)
# Passenger Boarding Bridge: Annual Cost
# Airfield Lighting Units
# People-Moving Systems
# BHS Conveying Systems
# PM Costs to Total Maintenance Costs
# Productive Hours to Labor Hours
# PMs Performed on Fleet Vehicles
# Cost per Covered Parking Space
# Cost per Parking Space with Busing
# Cost per Parking Space without Busing or Cover
# Overall Customer Satisfaction
# Customer Rating: Cleanliness of Terminal
# Customer Rating: Cleanliness of Restrooms
# Customer Rating:  Helpfulness of Staff
# Customer Rating:  Courtesy of Security Staff
# Percent MBW/WBE Purchases Under $5000
# Total MBW/WBE Purchases
# Total Passenger Flights
# Number of Direct Flights
# Number of Non-Stop Destinations
# Average Seats per Flight
# Total Annual Seats
# Total Annual Passengers
# Total Aviation FTEs
# Lost time Injury Rate
# Injuries Reportable
# Injuries with Medical
# Injuries without Medical
# Sick Hours Utilized
# Training Hours per FTE
# Employee Satisfaction Rating
# Percent Male Employees
# Percent Female Employees
# Percent White Employees
# Percent Hispanic Employees
# Percent Black Employees
# Percent Asian Employees
# Percent Employees Reporting Other
# Employee Turnover Rate: Percent
# Passenger Airline Cost per Enplanement
# Expenses per Enplaned Passenger
# Revenue per Enplanement
# Total Non-Airline Revenue
# Non-Airline Revenue per Passenger
# Non-Airline Revenue :: Airline Revenue
# Concession Revenue to Airport
# Concession Gross Sales per Square Foot
# Security Cost
# Security Cost :: Total Cost
# Repair and Maintenance Cost
# ARFF Cost
# ARFF Cost :: Total Cost
# ARFF Cost per Operation
# ARFF Salary and Benefits Cost
# Parking Revenue per Enplaned Passenger
# Parking and Ground Transportation: Total Revenue
# Parking and Ground Transportation: Off-Airport Revenue
# Parking and Ground Transportation: On-Airport Revenue
# Personnel Expenses
# Total Operating Revenue
# Total Landed Weight: Lbs
#
#
#
# eyec-w6nz : Austin Water - Registered Water Services Technicians
#
# TECHNICIAN
# EMPLOYER
# PHONE
#
#
#
# p4pj-6q8i : NET Deficiencies
#
# FOLDERRSN
# CASENUMBER
# DATE_OPENED
# CASE_TYPE
# STATUS
# PRIMARY_REPORTED_VIOLATION
# PROPX
# PROPY
# CATEGORYDESC
# ADDRESS
# LONGITUDE
# LATITUDE
# LOCATION
#
#
#
# 3gcv-xuei : Sales – kWh by Customer Class
#
# Fiscal Year
# Residential
# Commerical
# Industrial
# Public Street & Highway
# Government Entities
# Total Billed kWh
#
#
#
# jji9-e2m5 : AFD Fire Stations
#
# Station Name
# Station Number
# Station Address
# Station Facility
# Station Status
# Station Department
# Station Unit
#
#
#
# vyev-yeag : COA FUEL BY ICMA  Class
#
# ICMA_CLASS
# PROPANE
# E10_UNLEADED
# DIESEL
# BIODIESEL
# CNG
# E85
#
#
#
# bf4p-asz5 : EMS Patient Contacts Per Month City And County
#
# Month-Year
# Total Patient Contacts
# Austin Patient Contacts
# Travis County Patient Contacts
# Combined COA and TC Patient Contacts
#
#
#
# btjx-7fri : Total Work Orders Requested and Completed by Trade
#
# Trade/Craft
# Requested WOs
# Completed WOs
#
#
#
# dvu8-ztdx : Airport Quarterly Passenger Survey
#
# Quarter
# Date recorded
# Departure time
# Ground transportation to/from airport
# Parking facilities
# Parking facilities (value for money)
# Availability of baggage carts
# Efficiency of check-in staff
# Check-in wait time
# Courtesy of of check-in staff
# Wait time at passport inspection
# Courtesy of inspection staff
# Courtesy of security staff
# Thoroughness of security inspection
# Wait time of security inspection
# Feeling of safety and security
# Ease of finding your way through the airport
# Flight information screens
# Walking distance inside terminal
# Ease of making connections
# Courtesy of airport staff
# Restaurants
# Restaurants (value for money)
# Availability of banks/ATM/money changing
# Shopping facilities
# Shopping facilities (value for money)
# Internet access
# Business/executive lounges
# Availability of washrooms
# Cleanliness of washrooms
# Comfort of waiting/gate areas
# Cleanliness of airport terminal
# Ambience of airport
# Arrivals passport and visa inspection
# Speed of baggage delivery
# Customs inspection
# Overall satisfaction
#
#
#
# m4wb-q5fa : Austin Water - Gallons of Water and Wastewater Treated
#
# Year
# Month
# Plant
# Type of Water
# MG Treated
#
#
#
# m87q-f83v : Zilker Botanical Garden Sept-Nov 2015 events
#
# Date
# Event or Activity
# Location Name
# Time of Event
# Additional Information
#
#
#
# xtim-9ehs : Austin Water - Gallons of Water Treated
#
# Year
# Month
# Plant
# Type of Water
# MG Treated
#
#
#
# ubs4-99wr : August 2014 Austin Animal Center Outcomes Data
#
# Animal Type
# Outcome Type
# Animal Count
#
#
#
# 4cd2-vr8x : What' s Hot
#
# Title
#  Subtitle
#  Author
#  Publication Date
#  Format
#  Call Number
#  ISBN
#  Bibliocommons ID
#  Link
#
#
#
# 98zg-jkqu : COA INFO BY MAKE AND MODEL
#
# MAKE
# MODEL
# VEHICLE_COUNT
# MAINT_DOLLARS
# FUEL_QTY
# AVG_MILES_PER_VEHICLE
# TOTAL_MILES
#
#
#
# 7pv3-htyn : EPA Energy Star Portfolio Manager Score
#
# FACILITY
# ​P​M SCORE
#
#
#
# vsbg-t3e9 : City of Austin Performance Measures
#
# FY
# DEPARTMENT_NAME
# PROGRAM_NAME
# ACTIVITY_NAME
# PROGRAM_OBJECTIVE
# ACTIVITY_OBJECTIVE
# ACTIVITY_DESCRIPTION
# CORE_SERVICES
# SEMICORE_SERVICES
# OTHER_SERVICES
# CONTACT_INFO
# MEASURE_NAME
# MEASURE_DESCRIPTION
# KEY_PERFORMANCE
# DASHBOARD_IND
# LEVEL_NAME
# MEASURE_TYPE_NAME
# CURRENT_YR_PROJECTION
# PRIOR_YR1_PROJECTION
# PRIOR_YR1_ACTUAL
# PRIOR_YR2_ACTUAL
# PRIOR_YR3_ACTUAL
# PRIOR_YR4_ACTUAL
# FREQUENCY_NAME
# OCT_CURRENT_YR
# NOV_CURRENT_YR
# DEC_CURRENT_YR
# JAN_CURRENT_YR
# FEB_CURRENT_YR
# MAR_CURRENT_YR
# APR_CURRENT_YR
# MAY_CURRENT_YR
# JUN_CURRENT_YR
# JUL_CURRENT_YR
# AUG_CURRENT_YR
# SEP_CURRENT_YR
# QTR1_CURRENT_YR
# QTR2_CURRENT_YR
# QTR3_CURRENT_YR
# QTR4_CURRENT_YR
#
#
#
# un2z-dfva : Scheduled vs Unscheduled Maintenance
#
# FY15 - Q1, Q2, Q3 | Core Buildings
# Scheduled
# Unscheduled
# Total
# Ratio
#
#
#
# k5hp-eece : Electric Vehicle Charging Network
#
# Station Name
# Org Name
# No. of Ports
# Usable By
# Country
# Postal Code
# Customer Category
# Customer Subcategory
# Currency Name
# Station Activation Date
# Location 1
# Location 2
#
#
#
# 6tpg-refg : Brownfield Site List
#
# Location
# SITE IDENTIFICATION
# Zip Code
# ASSISTANCE TYPE
# PERIOD
# STATUS
# PROPOSED REDEVELOPMENT
# Acres
#
#
#
# qyb8-tmu7 : August 2014 Austin Animal Center Intakes Data
#
# Animal Type
# Intake Type
# Animal Count
#
#
#
# qunj-fzvx : Austin Public Library Social Media Presence
#
# Social Media
# Link
#
#
#
# 2cgz-29c8 : Austin's Small Scale Green Infrastructure
#
# Type of Green Infrastructure
# Zip
# location
#
#
#
# ux64-t7is : Austin Water - Active Permitted Industrial Users
#
# BUSINESS_NAME
# SERVICE_ADDRESS
# PERMIT_NUMBER
# PERMIT_TYPE
#
#
#
# 8spj-utxs : Single Member Council Districts
#
# _feature_id
# _feature_id_string
# the_geom
# objectid
# district_n
# district_1
# area
# perimeter
# compactnes
# population
# voting_age
# analysis1
# analysis2
# analysis3
# rgb
# countyspli
# precinctsp
# remainingb
# totalblock
# locked
# lockedby
# labelvalue
# originlaye
# originstfi
# originla_1
# timedate
# sid
# shape_leng
# edcode
# fedname
# shape_area
# shape_len
#
#
#
# ad4p-xsn6 : Plus 1 Fund
#
# Fiscal Year
# calendar_year
# calendar_month
# calendar_date_utc
# Dollars Dispersed
# Households Served
#
#
#
# ydgr-49yp : EMS Overall On- Time Rate -- Combined City And County
#
# Month-Year
# Combined Austin and Travis County Incidents
# Overall On-Time Compliance
# Target On-Time Compliance
#
#
#
# drfs-g7hw : FY14 HSEM Response Time - Open Data
#
# Payroll Period Ending Date
# Hours
#
#
#
# e7fj-wxvd : Power Supply Adjustment/Fuel Charge
#
# Calendar Year
# Month
# System (Cents/kWh)
# Secondary (Cents/kWh)
# Primary (Cents/kWh)
# Transmission (Cents/kWh)
#
#
#
# 8ih9-dnxa : Austin Water - Dillo Dirt Vendors
#
# NAME
# PHONE
# LOCATION
# Location 1
